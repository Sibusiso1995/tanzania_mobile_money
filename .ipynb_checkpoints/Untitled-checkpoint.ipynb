# %% [markdown]
# # Zindi Mobile Money and Financial Inclusion in Tanzania challenge

# %% [markdown]
# The train dataset contains demographic information and what financial services are used by approximately 10,000 individuals across Tanzania. This data was extracted from the FSDT Finscope 2017 survey and prepared specifically for this challenge. More about the Finscope survey here.
#
# Each individual is classified into four mutually exclusive categories:
#
#     • No_financial_services: Individuals who do not use mobile money, do not save, do not have credit, and do           not have insurance
#     • Other_only: Individuals who do not use mobile money, but do use at least one of the other financial
#       services (savings, credit, insurance)
#     • Mm_only: Individuals who use mobile money only
#     • Mm_plus: Individuals who use mobile money and also use at least one of the other financial services     (savings, credit, insurance) Financial Access Map
#
# This dataset is the geospatial mapping of all cash outlets in Tanzania in 2012. Cash outlets in this case included commercial banks, community banks, ATMs, microfinance institutions, mobile money agents, bus stations and post offices. This data was collected by FSDT.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import folium
from folium.plugins import MarkerCluster

# %% [markdown]
# # Examining the dataset

# %%
mobile_mon= pd.read_csv('training.csv')
mobile_mon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7094 entries, 0 to 7093
# Data columns (total 37 columns):
# ID                             7094 non-null int64
# Q1                             7094 non-null int64
# Q2                             7094 non-null int64
# Q3                             7094 non-null int64
# Q4                             7094 non-null int64
# Q5                             7094 non-null int64
# Q6                             7094 non-null int64
# Q7                             7094 non-null int64
# Q8_1                           7094 non-null int64
# Q8_2                           7094 non-null int64
# Q8_3                           7094 non-null int64
# Q8_4                           7094 non-null int64
# Q8_5                           7094 non-null int64
# Q8_6                           7094 non-null int64
# Q8_7                           7094 non-null int64
# Q8_8                           7094 non-null int64
# ...

# %% [markdown]
# This dataframe contains 7094 rows and 37 columns. There are 7094 ID entries meaning that it is working with 7094 people.

# %%
males = mobile_mon[mobile_mon.Q2 == 1]
females = mobile_mon[mobile_mon.Q2 == 2]

# %%
mobile_mon.rename(columns={
    'Q1':'Age', 'Q2':'Gender', 'Q3':'Marital_Status', 'Q4': 'Highest_level_of_education','Q5': 'Property_Ownership',
    'Q6': 'Land_Ownership', 'Q7': 'Mobile_Ownership', 'Q8_1':'Salaries_wages', 'Q8_2':'Trading','Q8_3':'Services',
    'Q8_4':'Casual_Work', 'Q8_5':'Rental_Income', 'Q8_6':'Interests', 'Q8_7':'Pension', 'Q8_8':'Social_Welfare',
    'Q8_9':'Financially_Dependant', 'Q8_10':'Third_Party', 'Q8_11':'Other', 'Q9':'Employer', 'Q10':'Selling_Things',
    'Q11':'Providing_Service', 'Q12':'Sent_money_past_(12 months)', 'Q13':'Money_last_sent', 
    'Q14':'Received_money_past_(12 months)', 'Q15':'Last_money_received', 'Q16':'Mobile_money_purchases',
    'Q17':'Mobile_money_bills', 'Q18':'Literacy_in_kwiswhahili', 'Q19':'Literacy_in_english'    
},inplace=True
)

# %% [markdown]
# # 1. Missing Values

# %%
missing_data = mobile_mon.isnull().sum().sum()
print('Number of missing values:',missing_data)
# Out:
# Number of missing values: 0

# %% [markdown]
# Having to examine the dataset I have found that it has no missing values

# %% [markdown]
# ### Mapping Columns

# %%
assign = {3:'Widowed', 1:'Married', 4:'Single', 2:'Divorced'}
mobile_mon['Marital_Status'] = mobile_mon['Marital_Status'].map(assign)

assign_1 = {2:'Female', 1:'Male'}
mobile_mon['Gender'] = mobile_mon['Gender'].map(assign_1)

assign_2 = {0:'None', 3:'Other_Only', 2:"MM_Only", 1:'MM_Plus'}
mobile_mon['mobile_money_classification'] = mobile_mon['mobile_money_classification'].map(assign_2)

assign_3 = {2:'No', 1:'Yes'}
mobile_mon['Land_Ownership'] = mobile_mon['Land_Ownership'].map(assign_3)

assign_4 = {0:'No', 1:'Yes'}
mobile_mon['Salaries_wages'] = mobile_mon['Salaries_wages'].map(assign_4)

assign_5 = {0:'No', 1:'Yes'}
mobile_mon['Trading'] = mobile_mon['Trading'].map(assign_5)

assign_6 = {0:'No', 1:'Yes'}
mobile_mon['Services'] = mobile_mon['Services'].map(assign_6)

assign_7 = {0:'No', 1:'Yes'}
mobile_mon['Casual_Work'] = mobile_mon['Casual_Work'].map(assign_7)

assign_8 = {0:'No', 1:'Yes'}
mobile_mon['Rental_Income'] = mobile_mon['Rental_Income'].map(assign_8)

assign_9 = {0:'No', 1:'Yes'}
mobile_mon['Interests'] = mobile_mon['Interests'].map(assign_9)

assign_10 = {0:'No', 1:'Yes'}
mobile_mon['Pension'] = mobile_mon['Pension'].map(assign_10)

assign_11 = {1:'Yes', 0:'No'}
mobile_mon['Social_Welfare'] = mobile_mon['Social_Welfare'].map(assign_11)

assign_12 = {1:'Yes', 0:'No'}
mobile_mon['Financially_Dependant'] = mobile_mon['Financially_Dependant'].map(assign_12)

assign_13 = {0:'No', 1:'Yes'}
mobile_mon['Third_Party'] = mobile_mon['Third_Party'].map(assign_13)

assign_14 = {0:'No', 1:'Yes'}
mobile_mon['Other'] = mobile_mon['Other'].map(assign_14)

assign_15 = {0:'No', 1:'Yes'}
mobile_mon['mobile_money'] = mobile_mon['mobile_money'].map(assign_15)

assign_16 = {1:'Yes', 2:'No'}
mobile_mon['Sent_money_past_(12 months)'] = mobile_mon['Sent_money_past_(12 months)'].map(assign_16)

assign_17 = {-1:'N/A', 4:'90 days', 2:'7 days', 5:'less than 6months', 3:'30 days', 6:'more than 6months', 1:'Yesterday/today'}
mobile_mon['Money_last_sent'] = mobile_mon['Money_last_sent'].map(assign_17)

assign_18 = {1:'Yes', 2:'No'}
mobile_mon['Received_money_past_(12 months)'] = mobile_mon['Received_money_past_(12 months)'].map(assign_18)

assign_19 = {-1:'N/A', 1:'Never', 2:'Daily', 3:'Weekly', 4:'Monthly', 5:'less often than monthly'}
mobile_mon['Last_money_received'] = mobile_mon['Last_money_received'].map(assign_19)

assign_20 = {-1:'N/A', 1:'Never', 2:'Daily', 3:'Weekly', 4:'Monthly', 5:'less often than monthly'}
mobile_mon['Mobile_money_purchases'] = mobile_mon['Mobile_money_purchases'].map(assign_20)

assign_21 = {-1:'N/A', 1:'Never', 2:'Daily', 3:'Weekly', 4:'Monthly', 5:'less often than monthly'}
mobile_mon['Mobile_money_bills'] = mobile_mon['Mobile_money_bills'].map(assign_21)

# %%
rem = mobile_mon.loc[:, 'Salaries_wages':'Other']
rem['mobile_money'] = mobile_mon['mobile_money']
rem = pd.melt(rem, id_vars = ['mobile_money'], var_name='Remuneration') 
rem = rem[rem['value'] == "Yes"]
rem.Remuneration.value_counts()
#rem.head()
# Out:
# Trading                  4470
# Casual_Work              2393
# Financially_Dependant    1112
# Salaries_wages            441
# Services                  412
# Third_Party               410
# Social_Welfare            131
# Rental_Income              67
# Interests                  34
# Pension                    34
# Other                       9
# Name: Remuneration, dtype: int64

# %% [markdown]
# Looking at the above dataframe you can separately see a breakdown of how many people who recieved different types of incomes.

# %% [markdown]
# # 2. Descriptive Statistics

# %%
mobile_mon.describe()
# Out:
#                 ID          Age  Highest_level_of_education  \
# count  7094.000000  7094.000000                 7094.000000
# mean   4742.627291    38.239498                    3.060051
# std    2731.120086    16.332148                    1.557779
# min       1.000000    16.000000                    1.000000
# 25%    2397.250000    25.000000                    2.000000
# 50%    4744.500000    35.000000                    3.000000
# 75%    7105.000000    48.000000                    3.000000
# max    9459.000000   100.000000                    8.000000
#
#        Property_Ownership  Mobile_Ownership     Employer  Selling_Things  \
# count         7094.000000       7094.000000  7094.000000     7094.000000
# mean             2.548915          1.397942    -0.794615        0.876092
# std              1.534257          0.489508     0.895007        2.172787
# min              1.000000          1.000000    -1.000000       -1.000000
# ...

# %% [markdown]
# The tabele above shows the mean, standard deviation, minimum, maximum and interquartile ranges for each column.

# %% [markdown]
# # 3. Visually presenting the data

# %% [markdown]
# ### Mobile money classification vs Age

# %%
sns.catplot(x='mobile_money_classification', y='Age', data=mobile_mon)
plt.xlabel("Mobile money classification")
plt.ylabel("Age")
plt.title('Mobile money classification vs Age')
# Out:
# Text(0.5, 1, 'Mobile money classification vs Age')

# %% [markdown]
# Judging from what we see in the graph is that from the age group of 20 - 40 mostly use mobile money and at least one other financial service. Most probably the reason for that could be that they have access to mobile devices and still literate with technological devices..

# %% [markdown]
# ### Mobile money classification vs Gender

# %%
total_males = len(males[males.mobile_money == 1]) + len(males[males.mobile_money == 0])
no_mm = len(males[males.mobile_money_classification == 1]) / total_males * 100
mmo = len(males[males.mobile_money_classification == 2]) / total_males * 100
both = len(males[males.mobile_money_classification == 3]) / total_males * 100
labels= ['Without mobile money', 'With mobile money', 'Both']
plt.pie([no_mm, mmo, both], explode=None, labels=labels, autopct='%1.1f%%')
plt.title("Comparison of all Male's use of Financial Services")
# Out:
# Text(0.5, 1.0, "Comparison of all Male's use of Financial Services")

# %%
total_females = len(females[females.mobile_money == 1]) + len(females[females.mobile_money == 0])
no_mm = len(females[females.mobile_money_classification == 1]) / total_females * 100
mmo = len(females[females.mobile_money_classification == 2]) / total_females * 100
both = len(females[females.mobile_money_classification == 3]) / total_females * 100
labels= ['Without mobile money', 'With mobile money', 'Both']
plt.pie([no_mm, mmo, both], explode=None, labels=labels, autopct='%1.1f%%')
plt.title("Comparison of all females use of Financial Services")
# Out:
# Text(0.5, 1.0, 'Comparison of all females use of Financial Services')

# %% [markdown]
# ### Mobile money classification vs Marital Status

# %%
sns.catplot(x='Marital_Status',kind='count', hue='mobile_money_classification', data=mobile_mon).set(xlabel='Marital Status')
plt.title('Mobile money classification vs Marital Status')
# Out:
# Text(0.5, 1, 'Mobile money classification vs Marital Status')

# %% [markdown]
# Mobile money and at least one other finacial service is mostly used by married people.

# %% [markdown]
# ### Mobile money classification vs Land Ownership

# %%
sns.catplot(x='Land_Ownership', kind= 'count', hue='mobile_money_classification', data=mobile_mon)
plt.xlabel('Land Ownership')
plt.ylabel('Number Of People')
# Out:
# Text(24.84213541666667, 0.5, 'Number Of People')

# %% [markdown]
# Most people who do not own land use mobile money and at least one of the financial services more than the ones who own land.

# %% [markdown]
# ### Mobile money classification vs Types of income

# %%
sns.countplot(y='Remuneration', hue= 'mobile_money', data= rem)
plt.ylabel('Income Type')
# Out:
# Text(0, 0.5, 'Income Type')

# %% [markdown]
# # 4. Mobile services used

# %% [markdown]
# ### Relationship between mobile money services used in Age

# %%
# Relationship between mobile money services used in Age
sns.catplot(x='Sent_money_past_(12 months)', y= 'Age', data= mobile_mon)
plt.title('Have you sent money to someone in past year?')
# Out:
# Text(0.5, 1, 'Have you sent money to someone in past year?')

# %%
g =sns.catplot(x='Money_last_sent', y='Age', kind='boxen', data=mobile_mon)
g.fig.set_figwidth(11.7)
g.fig.set_figheight(8.27)
plt.title('When last did you send money?')
# Out:
# Text(0.5, 1, 'When last did you send money?')

# %%
sns.catplot(x='Received_money_past_(12 months)', y='Age', kind='swarm', data=mobile_mon)
plt.title('Have you recieved money in the past year?')
# Out:
# Text(0.5, 1, 'Have you recieved money in the past year?')

# %%
g =sns.catplot(x='Last_money_received', y='Age', kind='swarm', data=mobile_mon)
g.fig.set_figwidth(11.7)
g.fig.set_figheight(8.27)
plt.title('When last did you send money?')
# Out:
# Text(0.5, 1, 'When last did you send money?')

# %%
g =sns.catplot(x='Last_money_received', y='Age', kind='boxen', data=mobile_mon)
g.fig.set_figwidth(11.7)
g.fig.set_figheight(8.27)
plt.title('When last did you recieve money?')
# Out:
# Text(0.5, 1, 'When last did you recieve money?')

# %%
g =sns.catplot(x='Mobile_money_purchases', y='Age', kind='boxen', data=mobile_mon)
g.fig.set_figwidth(11.7)
g.fig.set_figheight(8.27)
plt.title('How often people use mobile money for purchases')
# Out:
# Text(0.5, 1, 'How often people use mobile money for purchases')

# %%
g =sns.catplot(x='Mobile_money_bills', y='Age', kind='boxen', data=mobile_mon)
g.fig.set_figwidth(11.7)
g.fig.set_figheight(8.27)
plt.title('How often did you use mobile money for paying your bills?')
# Out:
# Text(0.5, 1, 'How often did you use mobile money for paying your bills?')

# %% [markdown]
# # Relationship between mobile money services used in Gender

# %%
# Relationship between mobile money services used in Gender
sns.countplot(x='Gender', hue= 'Sent_money_past_(12 months)', data=mobile_mon)
plt.title('Have you sent money to someone in past year?')
plt.ylabel('Number of people')
# Out:
# Text(0, 0.5, 'Number of people')

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Gender', hue= 'Money_last_sent', data=mobile_mon)
plt.ylabel('Number of people')
plt.title('When last did you send money?')
# Out:
# Text(0.5, 1.0, 'When last did you send money?')

# %%
sns.countplot(x='Gender', hue= 'Received_money_past_(12 months)', data=mobile_mon)
plt.ylabel('Number of people')
plt.title('Have you recieved money in the past year?')
# Out:
# Text(0.5, 1.0, 'Have you recieved money in the past year?')

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Gender', hue= 'Last_money_received', data=mobile_mon)
plt.ylabel('Number of people')
plt.title('When last did you send money?')
# Out:
# Text(0.5, 1.0, 'When last did you send money?')

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Gender', hue= 'Mobile_money_purchases', data=mobile_mon)
plt.ylabel('Number of people')
plt.title('How often people use mobile money for purchases')
# Out:
# Text(0.5, 1.0, 'How often people use mobile money for purchases')

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Gender', hue= 'Mobile_money_bills', data=mobile_mon)
plt.ylabel('Number of people')
plt.title('How often did you use mobile money for paying your bills?')
# Out:
# Text(0.5, 1.0, 'How often did you use mobile money for paying your bills?')

# %% [markdown]
# # Relationship between mobile money services used in Marital Status

# %%
## Relationship between mobile money services used in Marital Status 
sns.countplot(x='Sent_money_past_(12 months)', hue='Marital_Status', data=mobile_mon)
plt.ylabel('Number of people')
plt.title('Have you sent money to someone in past year?')
# Out:
# Text(0.5, 1.0, 'Have you sent money to someone in past year?')

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Marital_Status', hue='Money_last_sent', orient='h', data=mobile_mon)
plt.ylabel('Number of people')
# Out:
# Text(0, 0.5, 'Number of people')

# %% [markdown]
# ### Mobile money services used in Land Ownership

# %% [markdown]
# ### Relationship between mobile money services used in Types of Income

# %% [markdown]
# # 5.Geographic Map
